# %% [markdown]
# # Model Explainability

# %% [markdown]
# Setup & Assumptions
# Assumptions
#
# Binary target: is_fraud (1 = fraud, 0 = legit)
#
# Best model stored as best_model
#
# Test data: X_test, y_test
#
# Model is tree-based (RF, XGBoost, LightGBM)

# %%
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    f1_score,
    average_precision_score
)

# %% [markdown]
# # Feature Importance Baseline (Model-Built)

# %% [markdown]
# ## Extract Built-in Feature Importance

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Tenx_challenge_folder\fraud-detection\data\processed\creditcard_cleaned.csv")

# %%
X = df.drop(columns=["Class"])
y = df["Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2     X, y,
#       3     test_size=0.2,
#       4     stratify=y,
#       5     random_state=42
#       6 )
#
# NameError: name 'train_test_split' is not defined

# %%
feature_importance = pd.DataFrame({
    'feature': X_test.columns,
    'importance': rf_model.feature_importances_
}).sort_values(by='importance', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 feature_importance = pd.DataFrame({
#       2     'feature': X_test.columns,
#       3     'importance': rf_model.feature_importances_
#       4 }).sort_values(by='importance', ascending=False)
#
# NameError: name 'pd' is not defined

# %%
top10 = feature_importance.head(10)

plt.figure(figsize=(8,5))
plt.barh(top10['feature'], top10['importance'])
plt.gca().invert_yaxis()
plt.title("Top 10 Feature Importances (Model-Based)")
plt.xlabel("Importance")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 top10 = feature_importance.head(10)
#       3 plt.figure(figsize=(8,5))
#       4 plt.barh(top10['feature'], top10['importance'])
#
# NameError: name 'feature_importance' is not defined
